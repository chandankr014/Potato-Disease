# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNEL_SIZE = 3
EPOCHS = 20

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_name = dataset.class_names
class_name
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
L = len(dataset)
L
# Out:
# 68

# %%
type(dataset)
# Out:
# tensorflow.python.data.ops.batch_op._BatchDataset

# %%
for im, lb in dataset.take(1):
    print(im.shape)
    print(lb.numpy())
# Out:
# (32, 256, 256, 3)
# [1 1 0 0 0 1 1 0 0 0 2 0 0 0 1 1 1 0 1 0 2 1 1 1 0 1 1 1 0 1 0 1]

# %% [markdown]
# (32, 256, 256, 3) -> 32 batch size, 256,256 image size ,3 channel(RGB)

# %%
plt.figure(figsize=(16,8))
for im, lb in dataset.take(1):
    for i in range(32):
        ax = plt.subplot(4,8,i+1)
        plt.imshow(im[i].numpy().astype("uint8"))
        plt.title(class_name[lb[i]], fontsize=8)
        plt.axis("off")

# %% [markdown]
# 100 dataset,
# 80 -> training
# 20 -> 10-validation, 10-testing

# %%
L
# Out:
# 68

# %%
def data_split_function(dataset, train_size=0.8, test_size=0.1, val_size=0.1, shuffle=True, shuffle_size=3000):
    ds_size = len(dataset)
    if shuffle:
        dataset = dataset.shuffle(shuffle_size, seed=3)
    train_size = int(train_size*ds_size)
    val_size = int(val_size*ds_size)
    
    train_ds = dataset.take(train_size)

    val_ds = dataset.skip(train_size).take(val_size)

    test_ds = dataset.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_data, val_data, test_data = data_split_function(dataset)

# %%
len(train_data), len(val_data), len(test_data)
# Out:
# (54, 6, 8)

# %% [markdown]
# # preprocessing dataset

# %%
shfl=1000
train_data = train_data.cache().shuffle(shfl).prefetch(buffer_size=tf.data.AUTOTUNE)
val_data = val_data.cache().shuffle(shfl).prefetch(buffer_size=tf.data.AUTOTUNE)
test_data = test_data.cache().shuffle(shfl).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
data_augementation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomRotation(0.25),
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical")
])

# %%
image_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNEL_SIZE)
n_classes = 3 #early,late,healthy

# %%
model = models.Sequential([
    resize_rescale,
    data_augementation,
    
    # LAYER-1
    layers.Conv2D(32, (3,3), activation="relu", input_shape=image_shape),
    layers.MaxPooling2D((2,2)),
    
    # LAYER-2
    layers.Conv2D(32, activation="relu", kernel_size=(3,3)),
    layers.MaxPooling2D((2,2)),
    
    # LAYER-3
    layers.Conv2D(32, activation="relu", kernel_size=(3,3)),
    layers.MaxPooling2D((2,2)),
   
    # LAYER-4
    layers.Conv2D(32, activation="relu", kernel_size=(3,3)),
    layers.MaxPooling2D((2,2)),
   
    # LAYER-5
    layers.Conv2D(32, activation="relu", kernel_size=(3,3)),
    layers.MaxPooling2D((2,2)),
   
    # flatten and dense
    layers.Flatten(),
    layers.Dense(32, activation="relu"),
    layers.Dense(n_classes, activation="softmax")
    
])

# %%
model.build(input_shape=image_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2  (32, 127, 127, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (32, 62, 62, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 32)          9248
#
#  max_pooling2d_2 (MaxPoolin  (32, 30, 30, 32)          0
#  g2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 32)          9248
#
#  max_pooling2d_3 (MaxPoolin  (32, 14, 14, 32)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 32)          9248
#
#  max_pooling2d_4 (MaxPoolin  (32, 6, 6, 32)            0
#  g2D)
#
#  flatten (Flatten)           (32, 1152)                0
#
#  dense (Dense)               (32, 32)                  36896
#
#  dense_1 (Dense)             (32, 3)                   99
#
# =================================================================
# Total params: 74883 (292.51 KB)
# Trainable params: 74883 (292.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer="adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_data,
    epochs=10,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_data
)
# Out:
# Epoch 1/10
# 54/54 [==============================] - 155s 3s/step - loss: 0.8424 - accuracy: 0.5698 - val_loss: 0.6250 - val_accuracy: 0.7760
# Epoch 2/10
# 54/54 [==============================] - 146s 3s/step - loss: 0.4852 - accuracy: 0.8169 - val_loss: 0.5430 - val_accuracy: 0.7865
# Epoch 3/10
# 54/54 [==============================] - 169s 3s/step - loss: 0.4712 - accuracy: 0.8351 - val_loss: 0.4557 - val_accuracy: 0.8281
# Epoch 4/10
# 54/54 [==============================] - 160s 3s/step - loss: 0.3688 - accuracy: 0.8504 - val_loss: 0.2993 - val_accuracy: 0.8802
# Epoch 5/10
# 54/54 [==============================] - 150s 3s/step - loss: 0.2994 - accuracy: 0.8832 - val_loss: 0.2507 - val_accuracy: 0.9010
# Epoch 6/10
# 54/54 [==============================] - 143s 3s/step - loss: 0.2831 - accuracy: 0.8908 - val_loss: 0.2775 - val_accuracy: 0.8802
# Epoch 7/10
# 54/54 [==============================] - 160s 3s/step - loss: 0.2205 - accuracy: 0.9167 - val_loss: 0.2137 - val_accuracy: 0.9219
# Epoch 8/10
# 54/54 [==============================] - 154s 3s/step - loss: 0.1840 - accuracy: 0.9308 - val_loss: 0.2300 - val_accuracy: 0.9010
# Epoch 9/10
# 54/54 [==============================] - 1498s 28s/step - loss: 0.2045 - accuracy: 0.9137 - val_loss: 0.1905 - val_accuracy: 0.9427
# Epoch 10/10
# 54/54 [==============================] - 159s 3s/step - loss: 0.1741 - accuracy: 0.9319 - val_loss: 0.1817 - val_accuracy: 0.9271

# %% [markdown]
# ## plotting the history of model

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='Training Loss')
plt.plot(history.history['val_accuracy'], label='Validation Loss')
plt.legend()
plt.show()
